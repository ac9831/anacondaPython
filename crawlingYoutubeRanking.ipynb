# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd

browser = webdriver.Chrome('/usr/local/bin/chromedriver')

#페이지별 url 생성하기
results = []
for page in range(1, 11):
    url = f"https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page={page}"
    browser.get(url)
    time.sleep(2)
    html = browser.page_source
    soup = BeautifulSoup(html, 'html.parser')
    channel_list = soup.select('form > table > tbody > tr')
    for channel in channel_list:
        title = channel.select('h1 > a')[0].text.strip()
        category = channel.select('p.category')[0].text.strip()
        subscriber = channel.select('.subscriber_cnt')[0].text
        view = channel.select('.view_cnt')[0].text
        video = channel.select('.video_cnt')[0].text
        data = [title, category, subscriber, view, video]
        results.append(data)

print(results)
df = pd.DataFrame(results)
df.columns = ['title', 'category', 'subscriber', 'view', 'video']
df.to_excel('./files/youtube_rank.xlsx', index = False)
# Out:
# [['BLACKPINK', '[음악/댄스/가수]', '8200만', '271억1759만', '440개'], ['BANGTANTV', '[음악/댄스/가수]', '7090만', '179억9514만', '1,817개'], ['HYBE LABELS', '[음악/댄스/가수]', '6830만', '246억3109만', '1,003개'], ['SMTOWN', '[음악/댄스/가수]', '3100만', '256억3161만', '3,980개'], ['Boram Tube Vlog [보람튜브 브이로그]', '[키즈/어린이]', '2650만', '110억5288만', '223개'], ['JYP Entertainment', '[음악/댄스/가수]', '2570만', '176억7679만', '1,554개'], ['1MILLION Dance Studio', '[음악/댄스/가수]', '2560만', '74억9026만', '4,483개'], ['1theK (원더케이)', '[음악/댄스/가수]', '2420만', '228억2030만', '17,138개'], ['Mnet K-POP', '[음악/댄스/가수]', '1980만', '134억9041만', '29,296개'], ['KBS WORLD TV', '[TV/방송]', '1830만', '141억3469만', '59,389개'], ['officialpsy', '[음악/댄스/가수]', '1760만', '100억0252만', '120개'], ['JFlaMusic', '[음악/댄스/가수]', '1760만', '36억8248만', '283개'], ['Jane ASMR 제인', '[음식/요리/레시피]', '1690만', '66억2311만', '1,601개'], ['BIGBANG', '[음악/댄스/가수]', '1490만', '74억3534만', '776개'], ['TWICE', '[음악/댄스/가수]', '1480만', '40억1707만', '922개'], ['Boram Tube ToysReview [보람튜브 토이리뷰]', '[키즈/어린이]', '1440만', '49억2897만', '576개'], ['Hongyu ASMR 홍유', '[음식/요리/레시피]', '1390만', '44억4052만', '540개'], ['BIBO와 장난감', '[키즈/어린이]', '1260만', '29억5219만', '158개'], ['Kendrick Lamar', '[미분류]', '1140만', '50억0947만', '20개'], ['핑크퐁 (인기 동요・동화)', '[키즈/어린이]', '1100만', '67억4339만', '2,766개'], ['Stray Kids', '[음악/댄스/가수]', '1060만', '21억9352만', '638개'], ['DuDuPopTOY', '[키즈/어린이]', '1060만', '49억0284만', '2,264개'], ['Stone Music Entertainment', '[음악/댄스/가수]', '1050만', '90억8525만', '9,222개'], ['Toymong tv 토이몽TV', '[키즈/어린이]', '1050만', '43억3957만', '2,139개'], ['[햄지]Hamzy', '[음식/요리/레시피]', '1040만', '33억7057만', '482개'], ['서은일상이야기', '[키즈/어린이]', '1010만', '25억3400만', '706개'], ['MBCkpop', '[TV/방송]', '1000만', '83억5735만', '43,809개